# %%
# 首先下载语料，并将其转换为小写。
# 下载并解析初始文本文件
import keras
import numpy as np
path = keras.utils.get_file(
         'nietzsche.txt',
          origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 7s 12us/step
# Corpus length: 600893

# %%
# 将字符序列向量化
maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
# 用于预测下一个字符的单层 LSTM 模型
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /home/fc/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# 模型编译配置
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# 给定模型预测，采样下一个字符的函数
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 文本生成循环
import random
import sys
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        
        sys.stdout.write(generated_text)
        for i in range(400): 
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# WARNING:tensorflow:From /home/fc/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200278/200278 [==============================] - 261s 1ms/step - loss: 1.9887
# --- Generating with seed: "oul propounds to them (riddles which
# hegel systematised and "
# ------ temperature: 0.2
# oul propounds to them (riddles which
# hegel systematised and really and discour the man the man any a man the more any any the man the subjer the man the say the man any the sould the man to the more any the man the man the sould the man in the more and any the man in the sould the more any any the man the more any the more any the man the man the man the man and the spirit the man the self-relarnes of the man to the such a proble of the man in the one of t------ temperature: 0.5
# s of the man to the such a proble of the man in the one of the cillonces and even the subjer and scance the coll its really and realing and religious been any the man thore spiritions of the orgerance and
# the manimance of the man it he who has its life to a man in the pain the wase for the pullosy and one to the spiritual to the mident to call of the some canter of the mider that deens to the dind ant that who has probles of call man uself the more in the ------ temperature: 1.0
#  ant that who has probles of call man uself the more in the content taitation, things of higherto the wistordcalismive, others of badnest of soge habe xout of herecre; that great greems from of the
# man these
# will contror him one his "dore will of-the more is the "unwabse of rimpleatlos,
# with a stesiess
#
# fout hampeact in the selves know great in the morilicain was as sborge thingsrare, man spenience slimar more disinest har allom--as requiterity, unaat west------ temperature: 1.2
# e slimar more disinest har allom--as requiterity, unaat westable inflackfued, a le4tteming mamdor,"s
# a just cirinobiles. long  incastice spis "cleass not
# to ger a hend came falafalfual
# proinged,
# rowardhated, good yinly asminstines: who arequises lome who as t
# undofo4: or
# gediaths. reblerman stindsnou:d by nays
# ips ligitatly-atiortions -that hencessent. other--but his implast is s
# act of a uiful angreatcnsway practuithoo or
# glearm tooduit ciesprions befuttoepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 254s 1ms/step - loss: 1.6325
# --- Generating with seed: "r
# them, felt tremors and anxieties. this sentiment was frequ"
# ------ temperature: 0.2
# r
# them, felt tremors and anxieties. this sentiment was frequire and the perhaps the such a such a man a such a stands of the profess and the such a point the same the profound the profound the such a condection of the menself and they the such a standard and the such a standing the power and the such a standard to the world of the more and the such a stands the such a perhaps and the the profound the such a perhaps and the profess they the such a such the ------ temperature: 0.5
# the such a perhaps and the profess they the such a such the power the suches, the are good the prefore to absugates of a power of the manical to a  spirit they have the self for the philosophy, and the will the perhaps every their also the light and conditer and the sense of the smind of the man was the idmanting and the secomests and a complete and there is not the profess and the point to the something they of more good of the
# farter of the such they thi------ temperature: 1.0
# mething they of more good of the
# farter of the such they this shoatey of digne according a perture bothes:"me thereby perhist, what let never latted, through they they abuestapear wiodo, betthing or juch pithife, as through hoine which a chords and who reils terkinesrarity to be str in indiintor is dysistly an  belieny of emprobet have muchiloto
# in embetaly to make good "uses a delight be complised therewiles;" their day their and
# "emocars"1jusi
# mance
# han
# ------ temperature: 1.2
# d therewiles;" their day their and
# "emocars"1jusi
# mance
# han
# indigation. as siguts), that
# pet. "ortinage, croud hea" at hildo
# everyogard as hereomivra-grationely forespiching love ghavicals: the hary alicul in, "are to cauthed they "mastesm whichs subslusence,ler tiul here andisp tos ifemicareinained, people--  men a histort i themselsesy's manting
# conduenle. of platy one be.mentated, if no
# keal firtiinfur discomble, they unturradan, faminal of heaver beiepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 248s 1ms/step - loss: 1.5454
# --- Generating with seed: "-deceptions?"--that
# they please--him who has them, and him w"
# ------ temperature: 0.2
# -deceptions?"--that
# they please--him who has them, and him when the same all the strong and the same the same in the superiable and the self-desire and the strong and the part of the same one with the strong and the same the strong and such a propers and in the stronger and the same the strong and all the sense of the more and disponsible of the spiritual and the sense of the stronger and such a propers of the more and the same the same the propers and the------ temperature: 0.5
# ropers of the more and the same the same the propers and the same the stronger and the persists of a histerness of a medicting of the science of the good in the same in it is a men in the intellectually the delught in the spiritually this self-delution--which a dispine to the such a down to self-knowledge the part the strong same more the well with the sungained and the valuable to namely respect of all to be men and sounding the sconcasions and the all an------ temperature: 1.0
# of all to be men and sounding the sconcasions and the all an no irsemble erromed the
# plaling thuse of mament more a to form-is the
# were on the perhaps be loves, soul are almostly ining of the
# summlure of consponticity nowher. but that exemble, and from care. the science in distursly me his livently its vegre be question obtive-wito be dolus destimutly of us in the necast one of ideal and funcoment less) in them, a syeply the frenessity in such a presulaid ------ temperature: 1.2
#  less) in them, a syeply the frenessity in such a presulaid there.
#  gensed whero
# suen caves
# event'es,
# lag7.bitutter relutless un himself thes
# on, dambini
# actrer in caskgo.luhwe,
# a immaticmlinessic, now
# symes, and a madrinary becomes are denies" or priture almost one. pracifund and th
# symagy, upger
# adn?
# the igmoratence which at lad to not wenter
# atfine" eveny, thesuriligation
# and inouitible" strictgeously, reludical alm that
# elacts of powes
# tn the badmelm fepoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 248s 1ms/step - loss: 1.4994
# --- Generating with seed: "
# to convince themselves that the striving after english happ"
# ------ temperature: 0.2
#
# to convince themselves that the striving after english happiness of the spirit and the soul, there is the self-aboverally so that it is a mentered interropation of the self-personal self-selresh of the same the self-proved the soul, and in the great the soul, and soul, there is the self-persually the self-played to the self-persually self-seloosing the soul the self-selse of the self-aboverally soul, the soul, there is the self-part and the great the such------ temperature: 0.5
# oul, the soul, there is the self-part and the great the such and the star and as there are individual "modern whole great transities with the soul--that is the entitive in the semser as the really start, men of an all that there is not the strength him which the suncerunger--when they was the most sort of solitual belief in
# the great speciation and "are statent the self-suld will in the seasunder, and deference and not to the moralser with the world action------ temperature: 1.0
#  and deference and not to the moralser with the world actions
# of the cause," virturally a dut aividing infarsed itself! intols in the exergient greedly be him, in order to why
# refimate men,
# that class
# frefleshime
# to feel
# such the relaction of earloughtfrort. so troage with the most indoen
# ages
# us
# of our humanity and presuptive in the deselienly supare the belief whom they also
# thah can doether form, which man backed, with rest, themselves the relation: a b------ temperature: 1.2
# m, which man backed, with rest, themselves the relation: a being the giving -because ofly might--we masterp finally, they wholley, not this substitleneks, or idetijus make mas xtire, evil hedest: i bore to a perpondated,i there"--that it stined just whhys
# virtual present without fert their beings;
# crue there all proke to a"
# the estable playe it-itself upinity very etiletic
# shameflic
# "trues
# of thira of our har, they
# histonered god
# tim from net to calesary wepoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 244s 1ms/step - loss: 1.4700
# --- Generating with seed: "t seem that there is
# a hatred of the virgin forest and of th"
# ------ temperature: 0.2
# t seem that there is
# a hatred of the virgin forest and of the most can be life and the profound and despossible as the heart of the considered and the most still the most state of the more the creating the consequently and destructian and success and problem of the measure of the master and the most case have a propers of the most still propers of the more and success and more the same the same the most a man and the most accertion of the most success of t------ temperature: 0.5
# e most a man and the most accertion of the most success of the values. they have they among the cimours to be a chinds something the feared the more in the surence of the earth--and events and in the more his lack and matter the are only just are finer the feared to be
# the bad something things. they are
# a best and successed to the only on the certainly in the certain and the same the master which owe of the finer difficult respect to be feel in the moralit------ temperature: 1.0
# owe of the finer difficult respect to be feel in the morality placirity, perquarrful toul
# and inferenctedjy; he-poceding dinic may light themselves
# the cheressp disbeing of hir, lock themselves if care
# equally
# is they degrme how to all inture prourle des of the experience of higher--himself habje phypirity is highe, doy themselves a creating wind of menderation defenincine still fundamental will intricanist to
# mensamieating but
# them bednationate mankind wh------ temperature: 1.2
# ntricanist to
# mensamieating but
# them bednationate mankind what?
# alecismorudated people,
# are-charace been trio i god, in successable found of a : recogndicoric an attematifver pahts would among
# the highest in nob upor ame
# moftressp intoishe's no
# assures of acpootion
# to be place matger ;unosic
# pain, miso them reemy: thing
# and meputual moreof kind of mankind, a dang, danger this originalt--nimseves well (as to symstide, and actroble fecting of humanatentty
# anepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 243s 1ms/step - loss: 1.4486
# --- Generating with seed: "men
# have become so keen in the scrutiny of claims--constitut"
# ------ temperature: 0.2
# men
# have become so keen in the scrutiny of claims--constituted to the sense of the soul the consider to the consider to the present the sense of the sense the sense of the same the false of the consider of the same the soul and soul the sense of the sense of the existence of the exempt the soul of the standard of the same the means of the sense of the stronger which the sense of the same the means of the soul the sense of the reasure the certain the soul o------ temperature: 0.5
#  of the soul the sense of the reasure the certain the soul of the experience of the stronger what is not to the consider to the world be as the contempaled of the wors the sense it set at the sympathy of the same the man and decertain to created the standard, and calused to its been a god, one good tame the here and nothing of the act and strees the out to the sense the same the word in the soul and the means of the existence of the rest of morality. the s------ temperature: 1.0
# nd the means of the existence of the rest of morality. the stands, is learnt, moralities
# for
# coclite. it as meass and foringly, for enous to overcertain of
# ranking, and sought even create indeoleded, be does it is not an leable bound and lawagerial prejudice one of the certain our fast of tod unmenss to open, and profriberated by the artshuls, the now three are man allement; a conciss a ssbena, the inabilitasted ever the darn again to should diction, in a ------ temperature: 1.2
# e inabilitasted ever the darn again to should diction, in a "whole a cricide and, the soul, the delightesman latten into then
# oppernarles,
# to then, so to end into the fillo of does himself, so will with the signience of shollethanne the mede qual, by stillmence of a present why
# thun.
#
# star norrough all
# profest. that shameby,
# trouble,"--for men, the endoruable. pilt of act and , and
# sited because
# =there are
# harmelfule and succe, human yould
# naturalle-to a cepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 244s 1ms/step - loss: 1.4341
# --- Generating with seed: "e
# importance of things."
#
# [3] uebereinander: one over anothe"
# ------ temperature: 0.2
# e
# importance of things."
#
# [3] uebereinander: one over another and former and sense of the substraint to the sense of the sense of the serious the sense of the sense of the subtless of the sublibe and great one with the sense of the same thinking of the sense of the sense of the sense of the german the strived and the sense of the substinction of the same the sense of the substraint that the man all the substrnation of the subtless of the sense of the sense------ temperature: 0.5
# l the substrnation of the subtless of the sense of the sense of distinglitic for the entimunate learn and such a problem of religious that is an exceder and consider of far the subtle that is an existence to the german his plato, so that the most soul that a man also consider and virtues; the danger of the german perhaps with the sech the more promused and to the intellectual present that the delicing, who ho has the world with the eventure the standard wh------ temperature: 1.0
# cing, who ho has the world with the eventure the standard who
# knewed, namely. but why srantify the get there asceastomer, stie of "means nowrear sentimenture, as
# very man scientific scholared
# "wronche: founding which what freedomly. they recognized promosice that the genuing--he quill, of with ly
# great hard, certainly daces is not faid who preterst succe play, in sess as has not the exactition is it necessant; al, destaction wants "with solimutures the sub------ temperature: 1.2
# it necessant; al, destaction wants "with solimutures the sub
# circese in be
# such pared through
# culture as ertents: it good si, how who bolkwaysion not
# oped otherwheraps, ho
# doricts sundeusp. moreof gen or who are reprote and teorigal heavous but nowadays--nama a
# placizing, for cureble of threeke!--nembiporrque yimaniling moments).--in fame  scaured and
# that ver its freceilings, almost the
# ut, he wouks-sp: in this
# when a worldly, i       goo has thinking
# suepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 247s 1ms/step - loss: 1.4181
# --- Generating with seed: "the sake of whom one blesses and honours the fatherland, the"
# ------ temperature: 0.2
# the sake of whom one blesses and honours the fatherland, the same the sentiments of the sentiments of the sentiments of the same the most be all the states and and the more and the same the sentiments of the greatest of the present and the standard and the same the greatest to a promised to sense of the german so that the sentiments of the presentially and the standard and and the sentiments of the standard and some the standard of the present his soul and------ temperature: 0.5
# e standard and some the standard of the present his soul and even to the own condected princes to have been all the standard and according to the perhaps the secreticism and as in the sentimed what it does it is to his same the futively of the really some the manguage. the purity. the old and the morality and art of
# in the world, and as therefore the sentiments of an in the strong and property the been for the word to betreat,
# a means of the untain the ger------ temperature: 1.0
#  been for the word to betreat,
# a means of the untain the german exortinal will and have really a most should to too eorisbable, hear in whatherwis yourter
# halequersed too homes pass to the perfuishike difference as to in a predered in no recognical philosophy for a waillys.ijusis than etholly of manifest, to our something". the means because the and to teacher of
# distrust and agriear and prive
# 1bicipation of the learnang for with their says shortek. and mo------ temperature: 1.2
# cipation of the learnang for with their says shortek. and moral moin, heart.y" widiints instings, it is alponaovisy. in he fants it is t timet rupide sollect the
# encidlovo, for up of mindaur. in called a problems to be can regardence of the really nolduge and
# reducedive it? stackwa; not.
#
# 1lim. theyself, life, to spabitive
# ieresp
# shrong: and being edorised upsolitureve, i iplicends sasculs, inclistic weeces err has obvents the godfuar as a scielless usiol epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 246s 1ms/step - loss: 1.4057
# --- Generating with seed: "e lover of
# knowledge to hearken attentively and diligently; "
# ------ temperature: 0.2
# e lover of
# knowledge to hearken attentively and diligently; the sense of the same the subject that it is a strong as the self-salver and states and the fact the same the standard of the strong as the reason and subject the state of the same the sought of the self-salver as the states of the constraint of the conscience of the subject that the same the self-salved the self-self-self-self-sally and the sense of the conscience of the subject to the same with ------ temperature: 0.5
# the sense of the conscience of the subject to the same with the good and self-part of a standard and some without such a bounity! in the self-salver estempting to conscience of masters of its distrust of the subject of the way its amagest and speaks of mingral of the good with the fore more the fact which weaker of every explession of a cleasm of which the constrance. the philosophy, that the astract, the breaking the domance, that may most spiritial of th------ temperature: 1.0
# act, the breaking the domance, that may most spiritial of the string, out ole our virtuer, who god, of citcks of lack and meadable usiculati test
# to the german,
# the ogne conditions of whom comustal vertional
# psicl nature, in summluncieat much a good to one or their partet
# innitien), which in the wast
# dessomatical deteridion whom attentity: that is ut bact, brone; that exceptions. that whole contrive at hesher and lapers. a tording, are
# which there are brea------ temperature: 1.2
# ve at hesher and lapers. a tording, are
# which there are break glority); medandcull
# his
# self--that themselves to a has science, has fencepial sicking the
# questions to symparses by its
# comagried questy etmin.
# "very bationed" intoly
#  toanor, miturroun tnem has been veying unded authisoqpation, misunderstand that are maj
# cogran conscienced praise short, the distrust, as it honest who commugonke? that enough
# astentainsto payeded bay but viow necessi nsaily and epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 247s 1ms/step - loss: 1.3954
# --- Generating with seed: "eparates them from
# him: no difference in goodness or badness"
# ------ temperature: 0.2
# eparates them from
# him: no difference in goodness or badness and self-present and the stronger and artistion of the stronger to an individual constituted the self-present before the stronger of the stronger and self-present the stronger and arbitraries of the same the self-are of the self-all the sense of the spirit and the constituted to be and and the success and artistion of the stronger and self-destruction of the stronger and the constitute and the ar------ temperature: 0.5
# lf-destruction of the stronger and the constitute and the artistion and beaution of their presented to be little german and meaning friends of their spirit here and the second of the wailed to manifestal and one in the well of the propession of the concerned the same precisedor and the present promises to manifold have distrust and manaby and the religious and something and
# sands commandar in minds the stands and place of the soul, as if it is not to said ------ temperature: 1.0
# s the stands and place of the soul, as if it is not to said the heart of
# chursgint ventle of periosm and tain placed the manag are in--at sick, of manguous net.d.! (be knowledge,
# inspires verying concludelt scholarl
# bimid of the very been , to doy, but once
# the cleaker). under similians of instil soul
# to the whole and
# cotre too them could balod"
# of polisic before back evin prey dis of the reason that he was effect of the
# underpose hanle in constriorsly to ------ temperature: 1.2
# hat he was effect of the
# underpose hanle in constriorsly to soul and ageincbous" the
# vengens forewhere that
# the "no enimines raises spective me see our profounder fhough. "effect and breaking,--inde the det in a wholer.
#
#
# 1eyelyt what has notrot. selfiteled?
#             an tranfution
# selfination;
# thery character
# and gakans
# is to wey
# its "the a disguisubie tipen,
# andius wetejory, repussion of sudden yourn, to be hoved in prewile destrucrecuquently time theoepoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 244s 1ms/step - loss: 1.3874
# --- Generating with seed: "uch thing as moral phenomena, but only a moral
# interpretatio"
# ------ temperature: 0.2
# uch thing as moral phenomena, but only a moral
# interpretation and are also the moral one of the struggle of the most conscience of the spiritual and sense of the stronger to the present the present and of the moral men and the moral man are always the art and are a profound and are always the sense of the stronger in the sense and are the man are also be desire the of the moral men and the sense of the moral for the moral and the the conscience of the mora------ temperature: 0.5
# f the moral for the moral and the the conscience of the moral and
# such a time is at the proved by the concerning the are of him the point of a benority of himself in the strange, to the constraint of the sense of "profoundles souls--as the science and pation, of "with the concealed by a however him when the will the home and possible, in the enormour and antimont of the commander that the valual must there are distingtive and the desires the saster in the ------ temperature: 1.0
# ust there are distingtive and the desires the saster in the the obliged through, then tfindty
# opposite; a nothe, therewan notions, as the friends"--but the stoter, has intellent refurbed,
# and
# more prepared over
# justiful relance of will simples and furing he fact: it
# lasting interpond to say benough set leit select, the wawhy
# some, with the loves and judge formarits which had as the madness which me purpose.
#
# 1suhive as ebelime, for theil bee;
# new
# adybelowe------ temperature: 1.2
# e purpose.
#
# 1suhive as ebelime, for theil bee;
# new
# adybelowen often, i is lovestied rapedners, or cremilabled, to badkwauld apedmenes. "good over--cictud two certain treascetogical, kind, ole may
# not very with annation and doubtful mantery; divines quite from what who like, look
# inly should
# natureales. leg, heveraring early mack at intromisation. for one who majurgut free hume? and new, but out as compariunion. cittfoiss that
# indeiced to
# from with him, "whepoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 249s 1ms/step - loss: 1.3802
# --- Generating with seed: "glows--perhaps glows out. for this, we artists among the
# spe"
# ------ temperature: 0.2
# glows--perhaps glows out. for this, we artists among the
# special life and conscience of the stand and assertions and superiation and self-personal standard of the and the most instincts of the comparison of the most present that which we are all the constant the stand as the fact that the sense of the fact that the conscience of the fact that the self-stand of the self-personal super-itself which has also the most philosophers of the fact that which has al------ temperature: 0.5
# has also the most philosophers of the fact that which has also the galf at the opinion, and generally the
# sacrificed to an
# advantate for the self-course and have shring and where is like the belongs the self-responsiple in the germans it is all be in the made of the courses of mankind and many bad is in the states of the strength of conscience not from himself and generation of the fact that it may be more than the stand of the morality and above themselve------ temperature: 1.0
# y be more than the stand of the morality and above themselves the overlolonts
# and strange, that in all believes milexied of
# knot
# gloricality, itally astriglo, obcises
# grounds, and beterdulated must wish himself at all without world persons stands that have not be later to be indeed to understands to beings. why ). that
# thing men, long feelish lave stre, that are cause of dangerante of
# dingting apparance to nature must picl and typed, attemptialy, and thoug------ temperature: 1.2
# arance to nature must picl and typed, attemptialy, and thought which
# radiously--platr anotheriss, without weaking of
# moralityr.
#
#
# 13h
# aw
# condition something withicras,
# misunderstand formletis, i have as
# that it is hitherto whether icloary, germany the
# stoughte to its eginishnced hisselk lahken of this algorable moral faithrighters because to
# the
# bry--immgave iinn to cill that it.
#
#
# 18he been over
# ray, uselrage flood stayds--in lich chrostian, lafs otherphiepoch 13
# Epoch 1/1
# 130688/200278 [==================>...........] - ETA: 1:26 - loss: 1.3650
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e56eb69bdc9d> in <module>()
#       4 for epoch in range(1, 60):
#       5     print('epoch', epoch)
# ----> 6     model.fit(x, y, batch_size=128, epochs=1)
#       7     start_index = random.randint(0, len(text) - maxlen - 1)
#       8     generated_text = text[start_index: start_index + maxlen]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
